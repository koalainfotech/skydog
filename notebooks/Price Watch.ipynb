# %% [markdown]
# # Price Watch

# %%
#imports

import yfinance as yf
import pandas as pd
import datetime as dt
import seaborn as sns
from  matplotlib import pyplot as plt

#init
sns.set_theme(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, 
            rc={'figure.figsize':(15,10)})
pd.options.display.float_format = '{:,.2f}'.format

pd.set_option('display.max_rows', None)

print('This report was refrshed at:%s'%(dt.datetime.now()))
# Out:
# This report was refrshed at:2022-01-13 18:00:11.450056

# %%
def get_price_info(ticker):
    price_info={}
    df=yf.download(ticker,start=dt.date.today()-dt.timedelta(days=366),auto_adjust=True,progress=False)
    price_info['ticker']=ticker
    price_info['last_price']=df.Close[-1]
    price_info['1w_chg_pct']=100*(df.loc[max(df.index)-dt.timedelta(weeks=1):,'Close'][-1]/df.loc[max(df.index)-dt.timedelta(weeks=1):,'Close'][0]-1)
    price_info['1m_chg_pct']=100*(df.loc[max(df.index)-dt.timedelta(days=30):,'Close'][-1]/df.loc[max(df.index)-dt.timedelta(days=30):,'Close'][0]-1)
    price_info['1y_chg_pct']=100*(df.loc[max(df.index)-dt.timedelta(days=365):,'Close'][-1]/df.loc[max(df.index)-dt.timedelta(days=365):,'Close'][0]-1)
    price_info['drawdown_from_52w_peak']=100*(df.Close[-1]/max(df.Close)-1)
    price_info['diff_to_60d_avg']=100*(df.Close[-1]/df.Close[-60:].mean()-1)
    price_info['diff_to_200d_avg']=100*(df.Close[-1]/df.Close[-200:].mean()-1)
   
    return price_info

# %% [markdown]
# ## 大类资产

# %%
#parameters
ticker_list=['SPY','QQQ','MCHI','KWEB','2822.HK','GLD','BTC-USD','GSG','VNQ','TLT']


df_price_asset=pd.DataFrame()
for ticker in ticker_list:
    try:
        price_info=get_price_info(ticker)
        df_price_asset=df_price_asset.append(price_info,ignore_index=True)
    except:
        pass

# %%
df_price_asset.set_index('ticker').sort_values(by='drawdown_from_52w_peak')
# Out:
#          last_price  1w_chg_pct  1m_chg_pct  1y_chg_pct  \
# ticker
# KWEB          38.89       15.68       -7.03      -51.36
# BTC-USD   43,685.81        1.22       -6.28       17.07
# MCHI          65.18        8.27        1.29      -22.22
# 2822.HK       17.36       -0.74       -7.90      -18.73
# TLT          143.01        0.06       -5.22       -3.80
# VNQ          110.69       -0.88       -0.06       38.61
# GLD          170.74        0.99        2.24       -1.94
# QQQ          387.35        0.80       -1.13       23.99
# SPY          471.02        0.56        1.31       26.01
# GSG           18.19        4.60       10.11       39.60
#
#          drawdown_from_52w_peak  diff_to_60d_avg  diff_to_200d_avg
# ticker
# KWEB                     -62.45           -11.98            -30.57
# BTC-USD                  -35.34           -13.32             -9.75
# MCHI                     -32.30            -1.18            -10.14
# 2822.HK                  -25.37            -4.26             -6.44
# TLT                       -7.24            -2.87             -0.82
# VNQ                       -4.59             0.83              6.87
# GLD                       -4.49             1.30              1.41
# QQQ                       -4.00            -0.88              6.52
# SPY                       -1.40             1.55              7.59
# GSG                        0.00             5.49             12.22

# %% [markdown]
# ## 价值投资组合

# %%
#parameters
ticker_list=['FB','MSFT','AAPL','GOOG','AMZN',
'NVDA','0700.HK','ADBE','MO','ADSK','ASML','BRK-B',
'GS','ISRG','KO','LVMUY','2318.HK','TSM','ADBE','MCO'

]

df_price_value=pd.DataFrame()
for ticker in ticker_list:
    try:
        price_info=get_price_info(ticker)
        df_price_value=df_price_value.append(price_info,ignore_index=True)
    except:
        pass

# %%
df_price_value.set_index('ticker').sort_values(by='1w_chg_pct')
# Out:
#          last_price  1w_chg_pct  1m_chg_pct  1y_chg_pct  \
# ticker
# ISRG         323.16       -5.49       -5.05       22.96
# LVMUY        162.03       -4.32        1.88       29.77
# GS           390.31       -2.09        1.47       31.42
# MCO          372.90       -1.10       -6.49       37.08
# ASML         742.17       -0.47       -2.92       45.21
# KO            60.54       -0.41        4.81       24.62
# AAPL         175.53        0.35       -0.12       37.12
# AMZN       3,304.14        0.52       -2.57        5.87
# MSFT         318.27        0.60       -6.23       49.32
# NVDA         279.99        1.43       -0.58      107.82
# MO            49.49        1.75       11.20       29.91
# ADSK         269.60        2.00        0.27      -15.78
# FB           333.26        2.80       -0.37       32.73
# GOOG       2,832.96        2.90       -3.45       62.20
# BRK-B        320.39        3.38       10.48       37.49
# ADBE         532.37        3.49      -19.13       12.87
# ADBE         532.37        3.49      -19.13       12.87
# TSM          132.23        4.07       14.05        9.22
# 2318.HK       61.75        6.47        8.33      -36.47
# 0700.HK      473.20        8.28        2.91      -20.39
# BABA         137.41       13.41       12.41      -39.09
#
#          drawdown_from_52w_peak  diff_to_60d_avg  diff_to_200d_avg
# ticker
# ISRG                     -11.56            -6.56              0.79
# LVMUY                     -4.32             1.05              4.40
# GS                        -7.43            -1.53              2.96
# MCO                       -8.16            -4.06              2.31
# ASML                     -16.33            -7.07             -0.40
# KO                        -0.41             7.23             10.52
# AAPL                      -3.56             7.43             20.35
# AMZN                     -11.45            -3.76             -2.64
# MSFT                      -7.24            -3.32              9.70
# NVDA                     -16.10            -3.16             29.09
# MO                        -2.08             9.05              6.93
# ADSK                     -21.23            -7.19             -8.06
# FB                       -12.80             0.23             -1.20
# GOOG                      -6.01            -2.42              5.68
# BRK-B                      0.00             9.97             13.06
# ADBE                     -22.66           -14.22             -9.37
# ADBE                     -22.66           -14.22             -9.37
# TSM                       -4.08            10.63             13.16
# 2318.HK                  -37.76             7.40             -8.42
# 0700.HK                  -38.10             0.98             -9.11
# BABA                     -49.26            -2.45            -24.09

# %% [markdown]
# ## 趋势投资组合

# %%
#parameters
ticker_list=['KWEB','META','ARKK','TAL','DAO','BABA','BIDU','RMD.AX','BA',
'ABNB','COIN',"DIS","ATVI"

]

df_price_trend=pd.DataFrame()
for ticker in ticker_list:
    try:
        price_info=get_price_info(ticker)
        df_price_trend=df_price_trend.append(price_info,ignore_index=True)
    except:
        pass

# %%
df_price_trend.set_index('ticker').sort_values(by='1w_chg_pct',ascending=False)
# Out:
#         last_price  1w_chg_pct  1m_chg_pct  1y_chg_pct  \
# ticker
# DAO          14.72       22.46       28.22      -44.68
# KWEB         38.89       15.68       -7.03      -51.36
# BABA        137.41       13.41       12.41      -39.09
# BIDU        159.36       10.76       10.25      -33.45
# TAL           3.66        7.33      -21.29      -94.41
# ABNB        169.54        4.49       -0.88        5.44
# BA          217.45        2.06       10.16        4.34
# META         14.53        2.04       -4.66       -3.90
# DIS         157.80        1.68        4.90      -10.34
# COIN        234.70        0.20       -6.63      -28.51
# RMD.AX       33.59       -0.15       -9.17       21.04
# ARKK         84.56       -1.81       -9.78      -39.53
# ATVI         64.81       -2.23       10.41      -27.03
#
#         drawdown_from_52w_peak  diff_to_60d_avg  diff_to_200d_avg
# ticker
# DAO                     -64.40            12.62            -12.24
# KWEB                    -62.45           -11.98            -30.57
# BABA                    -49.26            -2.45            -24.09
# BIDU                    -53.12             2.74             -7.72
# TAL                     -95.94           -15.79            -80.50
# ABNB                    -21.81            -3.73              4.50
# BA                      -19.22             3.96             -3.32
# META                    -14.02            -6.14             -3.42
# DIS                     -21.85            -0.29             -8.56
# COIN                    -34.33           -19.39            -11.30
# RMD.AX                  -16.80            -5.68              0.37
# ARKK                    -45.55           -19.48            -25.42
# ATVI                    -37.27            -2.21            -20.48

# %% [markdown]
# ## QQQ Holdings

# %%
df_port=pd.read_csv('../data/share/qqq_holdings.csv')
ticker_list=df_port['Ticker'].drop_duplicates()

df_price_qqq=pd.DataFrame()
for ticker in ticker_list:
    try:
        price_info=get_price_info(ticker)
        df_price_qqq=df_price_qqq.append(price_info,ignore_index=True)
    except:
        pass

# %%
df_price_qqq.set_index('ticker').sort_values(by='drawdown_from_52w_peak')
# Out:
#         last_price  1w_chg_pct  1m_chg_pct  1y_chg_pct  \
# ticker
# PTON         34.49        7.01      -16.57      -77.90
# PDD          60.38       24.42       -2.00      -64.37
# ZM          170.65       -2.42       -7.54      -52.17
# DOCU        139.25       -3.41       -0.37      -46.98
# MRNA        222.89        3.56      -18.05       78.96
# BIDU        159.36       10.76       10.25      -33.45
# BIIB        225.34       -5.82       -3.91      -15.73
# PYPL        187.20        0.02        0.44      -21.23
# MELI      1,210.91        7.19        2.62      -33.10
# ATVI         64.81       -2.23       10.41      -27.03
# CRWD        187.97        4.84       -5.39      -19.53
# SPLK        121.46        8.21        8.93      -27.27
# TEAM        320.59        2.87      -13.34       36.89
# MTCH        124.08       -1.15       -1.68      -19.20
# JD           76.40       21.23       -2.11      -13.71
# OKTA        213.93        7.72       -3.60      -16.48
# LULU        352.72       -2.69      -12.64       -1.18
# SGEN        141.03       -3.17       -2.18      -21.81
# ALGN        539.47       -6.80      -14.36       -2.43
# TMUS        110.85       -3.91       -3.62      -13.86
# ZS          273.98        4.44      -11.20       33.06
# DDOG        146.33        0.56      -14.94       38.60
# CHTR        613.98       -1.74        1.39       -1.21
# DXCM        490.38        0.53      -10.78       36.15
# ADBE        532.37        3.49      -19.13       12.87
# NFLX        537.22       -5.34      -11.14        8.69
# ABNB        169.54        4.49       -0.88        5.44
# LCID         45.43       23.85       16.04      221.06
# IDXX        554.63       -4.94       -8.38       11.66
# ILMN        413.37       12.37        8.91       14.42
# ADSK        269.60        2.00        0.27      -15.78
# SWKS        156.11       -1.25       -2.13       -0.09
# ROST        105.44       -3.85       -3.87      -12.12
# EBAY         64.32       -0.26       -3.55       16.05
# NTES        106.01       11.05        2.91       -0.56
# SBUX        103.87       -5.95      -10.12        2.69
# INTU        577.26       -2.66      -13.58       58.66
# INTC         55.74        3.47       11.48        7.41
# CMCSA        50.95        1.45        7.32        3.75
# ASML        742.17       -0.47       -2.92       45.21
# NVDA        279.99        1.43       -0.58      107.82
# XLNX        197.87       -1.88       -5.56       35.16
# AMD         137.47        0.97        2.74       44.16
# WDAY        257.96        3.91       -8.17       14.33
# FISV        108.50        0.13        4.04       -2.43
# KHC          37.30        1.47        8.18       20.84
# FB          333.26        2.80       -0.37       32.73
# SPLK                    -30.63            -9.33            -11.16
# TEAM                    -30.02           -18.18             -0.77
# MTCH                    -29.31           -11.40            -15.60
# JD                      -28.52            -2.41              0.79
# OKTA                    -26.68            -8.58            -11.27
# LULU                    -26.20           -16.90             -8.32
# SGEN                    -26.11           -14.29            -10.03
# ALGN                    -26.09           -15.30            -15.08
# TMUS                    -25.81            -4.67            -15.23
# ZS                      -25.71           -13.72              8.36
# DDOG                    -25.55           -14.76             12.93
# CHTR                    -25.22            -7.80            -12.38
# DXCM                    -24.70           -14.00              0.55
# ADBE                    -22.66           -14.22             -9.37
# NFLX                    -22.33           -14.78             -5.17
# ABNB                    -21.81            -3.73              4.50
# LCID                    -21.74            11.00             61.37
# IDXX                    -21.41           -10.85             -9.87
# ILMN                    -21.24             6.97             -2.42
# ADSK                    -21.23            -7.19             -8.06
# SWKS                    -21.06            -1.99             -9.20
# ROST                    -20.11            -5.82            -10.54
# EBAY                    -19.98            -8.33             -5.68
# NTES                    -19.34             2.76              4.40
# SBUX                    -16.93            -7.57             -8.42
# INTU                    -16.80            -8.21              8.73
# INTC                    -16.73             9.35              2.87
# CMCSA                   -16.71            -0.37             -6.91
# ASML                    -16.33            -7.07             -0.40
# NVDA                    -16.10            -3.16             29.09
# XLNX                    -15.11            -3.86             24.77
# AMD                     -15.09            -2.15             28.35
# WDAY                    -14.27            -7.22              1.07
# FISV                    -14.26             5.09             -1.72
# KHC                     -13.54             4.47             -1.36
# FB                      -12.80             0.23             -1.20
# FTNT                    -12.75            -3.44             15.03
# CPRT                    -11.58            -5.58              1.59
# ISRG                    -11.56            -6.56              0.79
# AMZN                    -11.45            -3.76             -2.64
# CTAS                    -11.39            -6.26              3.72
# CDNS                    -11.20            -4.64             10.61
# EA                      -10.61            -0.62             -4.21
# SIRI                    -10.21             0.74              1.38
# TSLA                    -10.06             4.50             38.24
# ANSS                     -9.99            -5.14              1.64
# SNPS                     -9.85            -2.12             12.89
# VRSK                     -9.73            -5.58              5.47
# AMGN                     -8.48             8.59              2.38
# BKNG                     -8.01             3.26              4.97
# AVGO                     -7.75             6.56             23.58
# ADI                      -7.62            -2.54              3.72
# COST                     -7.39            -0.52             17.83
# REGN                     -7.27             0.62              8.50
# MSFT                     -7.24            -3.32              9.70
# MRVL                     -7.11             8.38             36.89
# TXN                      -7.01            -2.53             -1.29
# VRSN                     -6.91             0.45              6.66
# PAYX                     -6.62             2.11             14.41
# DLTR                     -6.62             6.56             24.42
# PANW                     -6.39             1.37             22.13
# VRTX                     -6.29            12.41             12.73
# FAST                     -6.27             0.01              9.80
# HON                      -6.22             2.37             -0.73
# GOOG                     -6.01            -2.42              5.68
# GOOGL                    -5.61            -2.22              6.70
# LRCX                     -5.56             5.83             10.30
# ADP                      -5.39             1.30             12.50
# MNST                     -4.87             4.51              1.58
# MCHP                     -4.61             2.78             10.20
# PCAR                     -4.38             6.37              8.01
# NXPI                     -3.89             4.64             10.75
# CTSH                     -3.66             6.95             15.28
# XEL                      -3.57             4.57              2.86
# AAPL                     -3.56             7.43             20.35
# ORLY                     -3.47             3.35             14.04
# EXC                      -3.06             3.68             15.59
# CSX                      -2.84             1.67              9.62
# WBA                      -2.39             9.77              8.72
# CSCO                     -2.30             7.30             13.22
# MAR                      -2.10             4.04             11.57
# AMAT                     -1.95             6.80             15.12
# GILD                     -1.89             4.56              6.90
# QCOM                     -1.51             9.89             27.41
# KLAC                     -1.43             7.73             24.43
# MU                       -1.28            15.87             19.35
# AEP                      -0.56             6.11              6.19
# MDLZ                     -0.27             7.65              9.72
# PEP                      -0.16             4.94             13.14
# KDP                       0.00             7.03              8.52

# %% [markdown]
# ## KWEB Holdings

# %%
df_port=pd.read_csv('../data/share/kweb_holdings.csv')
ticker_list=df_port['Ticker'].drop_duplicates()

df_price_kweb=pd.DataFrame()
for ticker in ticker_list:
    try:
        price_info=get_price_info(ticker)
        df_price_kweb=df_price_kweb.append(price_info,ignore_index=True)
    except:
        pass

# %%
df_price_kweb.set_index('ticker').sort_values(by='1w_chg_pct',ascending=False)
# Out:
#          last_price  1w_chg_pct  1m_chg_pct  1y_chg_pct  \
# ticker
# BEKE          22.78       33.29       21.62      -65.48
# YMM            9.55       29.58      -11.41      -54.52
# 1024.HK       85.05       25.17        3.09      -71.65
# PDD           60.38       24.42       -2.00      -64.37
# DAO           14.72       22.46       28.22      -44.68
# VIPS           9.55       22.44        6.11      -67.46
# JD            76.40       21.23       -2.11      -13.71
# 6618.HK       64.65       19.83       -6.44      -55.48
# ATHM          37.00       17.83       19.28      -64.75
# IQ             4.92       17.42        1.23      -74.73
# 0241.HK        6.82       16.18       -7.21      -69.21
# DADA          12.32       16.01      -21.23      -72.73
# YY            53.39       15.86        8.96      -36.09
# TME            7.34       15.77       14.15      -65.80
# 9618.HK      292.20       13.87       -4.01      -15.70
# ZH             5.33       13.65      -12.77      -37.29
# HUYA           7.43       13.61       -0.67      -64.48
# BABA         137.41       13.41       12.41      -39.09
# GOTU           1.83       12.96      -18.30      -96.04
# VNET           9.28       12.62       13.03      -76.03
# 2013.HK        7.76       12.30       -3.48      -57.41
# 1060.HK        0.84       12.00       10.53      -11.58
# DOYU           2.65       11.81        4.33      -77.50
# CD             6.18       11.55       -4.48      -65.36
# 3690.HK      224.80       11.18       -8.69      -24.16
# NTES         106.01       11.05        2.91       -0.56
# BIDU         159.36       10.76       10.25      -33.45
# MOMO           9.62       10.57        2.01      -35.27
# KC            14.15       10.29       -7.94      -70.00
# API           15.36       10.19      -11.32      -61.50
# BILI          41.70        9.88      -24.95      -63.88
# WB            35.10        9.76       17.47      -15.71
# BZUN          14.23        9.55        0.35      -60.28
# OCFT           2.54        9.48       -1.93      -88.58
# 9626.HK      313.60        9.34      -27.84      -60.80
# 3888.HK       36.15        8.89        6.17      -36.50
# 0772.HK       51.50        8.88      -12.86       -4.54
# 9988.HK      131.50        8.68       10.78      -41.24
# 0700.HK      473.20        8.28        2.91      -20.39
# 9999.HK      162.30        8.20        1.88       -0.33
# 6060.HK       29.15        7.96        5.23      -26.57
