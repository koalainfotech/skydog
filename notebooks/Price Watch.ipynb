# %% [markdown]
# # Price Watch

# %%
#imports

import yfinance as yf
import pandas as pd
import datetime as dt
import seaborn as sns
from  matplotlib import pyplot as plt

#init
sns.set_theme(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, 
            rc={'figure.figsize':(15,10)})
pd.options.display.float_format = '{:,.2f}'.format

pd.set_option('display.max_rows', None)

print('This report was refrshed at:%s'%(dt.datetime.now()))
# Out:
# This report was refrshed at:2022-07-25 20:03:22.503135

# %%
def get_price_info(ticker):
    price_info={}
    df=yf.download(ticker,start=dt.date.today()-dt.timedelta(days=366),auto_adjust=True,progress=False)
    price_info['ticker']=ticker
    price_info['last_price']=df.Close[-1]
    price_info['1w_chg_pct']=100*(df.loc[max(df.index)-dt.timedelta(weeks=1):,'Close'][-1]/df.loc[max(df.index)-dt.timedelta(weeks=1):,'Close'][0]-1)
    price_info['2w_chg_pct']=100*(df.loc[max(df.index)-dt.timedelta(weeks=2):,'Close'][-1]/df.loc[max(df.index)-dt.timedelta(weeks=2):,'Close'][0]-1)
    price_info['1m_chg_pct']=100*(df.loc[max(df.index)-dt.timedelta(days=28):,'Close'][-1]/df.loc[max(df.index)-dt.timedelta(days=28):,'Close'][0]-1)
    price_info['1y_chg_pct']=100*(df.loc[max(df.index)-dt.timedelta(days=365):,'Close'][-1]/df.loc[max(df.index)-dt.timedelta(days=365):,'Close'][0]-1)
    price_info['drawdown']=100*(df.Close[-1]/max(df.Close)-1)
    price_info['diff_to_60d_avg']=100*(df.Close[-1]/df.Close[-60:].mean()-1)
    price_info['diff_to_200d_avg']=100*(df.Close[-1]/df.Close[-200:].mean()-1)
   
    return price_info

# %% [markdown]
# ## 大类资产

# %%
#parameters
ticker_list=['SPY','QQQ','MCHI','KWEB','2822.HK','GLD','BTC-USD','GSG','VNQ','TLT','SPLV']

df_price_asset=pd.DataFrame()
for ticker in ticker_list:
    try:
        price_info=get_price_info(ticker)
        df_price_asset=df_price_asset.append(price_info,ignore_index=True)
    except:
        pass

# %%
df_price_asset
# Out:
#      ticker  last_price  1w_chg_pct  2w_chg_pct  1m_chg_pct  1y_chg_pct  \
# 0       SPY      395.09        2.59        1.65        1.28       -8.92
# 1       QQQ      301.99        3.47        2.25        2.51      -17.53
# 2      MCHI       51.36        0.10       -7.49       -7.97      -30.48
# 3      KWEB       29.91        2.50       -6.85      -10.48      -41.94
# 4   2822.HK       15.24       -1.68       -3.18       -5.75      -13.90
# 5       GLD      160.67        1.04       -1.00       -5.54       -4.68
# 6   BTC-USD   22,014.58       -2.10       10.24        6.17      -37.72
# 7       GSG       21.92        0.14       -3.73       -8.02       36.57
# 8       VNQ       94.51        2.96        2.64        1.49       -8.24
# 9       TLT      118.55        2.08        5.38        5.53      -18.79
# 10     SPLV       61.98        0.46       -0.06       -0.12        0.12
#
#     drawdown  diff_to_60d_avg  diff_to_200d_avg
# 0     -16.68             0.31             -8.45
# 1     -24.92             2.02            -12.58
# 2     -30.48            -0.45            -11.85
# 3     -41.94             1.37            -13.91
# 4     -20.08             1.08             -8.02
# 5     -16.10            -5.17             -6.52
# 6     -67.42            -6.42            -36.46
# 7     -16.78            -8.53              5.36
# 8     -17.57            -0.10             -8.08
# 9     -22.36             2.96            -10.12
# 10    -10.22            -1.23             -3.09

# %%
df_price_asset.set_index('ticker').sort_values(by='1m_chg_pct')
# Out:
#          last_price  1w_chg_pct  2w_chg_pct  1m_chg_pct  1y_chg_pct  drawdown  \
# ticker
# BTC-USD   19,761.07       -2.13       -2.56      -26.16      -40.40    -70.75
# GSG           22.76        4.16       -4.93      -11.68       42.07    -13.59
# GLD          161.43       -2.02       -4.99       -5.00       -4.48    -15.71
# KWEB          29.93       -9.98      -10.68        1.70      -51.55    -53.06
# SPY          384.23        0.59       -1.12        2.46      -12.09    -19.57
# SPLV          62.18        0.37       -0.30        3.31        0.07    -10.43
# MCHI          53.05       -4.62       -5.20        3.71      -31.52    -32.81
# TLT          114.44       -1.96        2.54        3.85      -21.80    -25.86
# VNQ           91.88       -0.66       -1.18        4.42      -13.29    -20.80
# QQQ          289.04        0.72       -1.17        4.95      -20.25    -28.45
# 2822.HK       15.56       -4.13       -4.42        5.28      -18.45    -19.25
#
#          diff_to_60d_avg  diff_to_200d_avg
# ticker
# BTC-USD           -21.66            -45.55
# GSG                -5.99             10.63
# GLD                -6.53             -6.17
# KWEB                3.40            -17.80
# SPY                -4.44            -11.99
# SPLV               -2.78             -3.66
# MCHI                3.24            -10.58
# TLT                -1.51            -14.75
# VNQ                -5.88            -12.11
# QQQ                -4.44            -17.30
# 2822.HK             3.37             -6.58

# %% [markdown]
# ## 价值投资组合

# %%
#parameters
ticker_list=['FB','MSFT','AAPL','GOOG','AMZN',
'NVDA','0700.HK','ADBE','MO','ADSK','ASML','BRK-B',
'GS','ISRG','KO','LVMUY','2318.HK','TSM','MCO'

]

df_price_value=pd.DataFrame()
for ticker in ticker_list:
    try:
        price_info=get_price_info(ticker)
        df_price_value=df_price_value.append(price_info,ignore_index=True)
    except:
        pass

# %%
df_price_value.set_index('ticker').sort_values(by='1w_chg_pct')
# Out:
#          last_price  1w_chg_pct  2w_chg_pct  1m_chg_pct  1y_chg_pct  drawdown  \
# ticker
# 2318.HK       51.35       -3.66       -5.61        9.84      -23.89    -26.02
# FB           162.88       -3.16       -3.90       -0.84      -53.88    -57.38
# 0700.HK      337.80       -3.15       -7.65      -10.40      -36.50    -39.93
# AMZN         111.75       -1.54       -1.30        7.79      -39.90    -39.90
# GS           293.18       -1.35       -2.53        3.48      -21.23    -29.63
# KO            62.94       -0.54        0.05        3.35       19.06     -4.25
# ISRG         205.72       -0.50       -1.07        5.51      -35.65    -43.70
# ADSK         176.72       -0.10       -4.92        2.09      -39.46    -48.37
# MO            41.95        0.55       -2.87       -9.32       -4.93    -24.40
# MSFT         264.51        0.63       -0.14        9.18       -3.84    -22.57
# BRK-B        278.51        1.02        0.04       -1.08       -0.57    -22.54
# LVMUY        120.78        1.05       -1.32        5.30      -22.70    -27.88
# NVDA         151.52        1.26      -10.18       -3.16      -26.08    -54.58
# MCO          283.64        1.28        2.10        6.89      -23.77    -29.82
# ASML         439.06        1.54      -13.58      -11.05      -37.35    -50.14
# ADBE         384.16        2.04        0.81        3.37      -35.99    -44.19
# GOOG       2,330.45        2.31       -0.09        9.03      -10.75    -22.68
# AAPL         144.87        2.34        2.27        9.85        0.83    -20.19
# TSM           79.11        3.94       -7.86       -7.04      -34.30    -43.19
#
#          diff_to_60d_avg  diff_to_200d_avg
# ticker
# 2318.HK             3.75             -4.96
# FB                -12.55            -37.09
# 0700.HK            -5.83            -19.57
# AMZN               -6.49            -25.45
# GS                 -4.63            -16.15
# KO                 -0.21              6.54
# ISRG               -8.27            -29.00
# ADSK               -6.49            -25.85
# MO                -15.78            -11.81
# MSFT               -0.81            -10.87
# BRK-B              -8.83             -8.93
# LVMUY              -2.68            -15.53
# NVDA              -14.74            -35.58
# MCO                -2.76            -16.22
# ASML              -18.07            -34.28
# ADBE               -3.70            -23.89
# GOOG                0.91            -12.15
# AAPL               -2.02             -8.29
# TSM               -11.70            -26.17

# %% [markdown]
# ## 趋势投资组合

# %%
#parameters
ticker_list=['KWEB','META','ARKK','TAL','DAO','BABA','BIDU','RMD.AX','BA',
'ABNB','COIN',"DIS","ATVI"

]

df_price_trend=pd.DataFrame()
for ticker in ticker_list:
    try:
        price_info=get_price_info(ticker)
        df_price_trend=df_price_trend.append(price_info,ignore_index=True)
    except:
        pass

# %%
df_price_trend.set_index('ticker').sort_values(by='1w_chg_pct',ascending=False)
# Out:
#         last_price  1w_chg_pct  2w_chg_pct  1m_chg_pct  1y_chg_pct  drawdown  \
# ticker
# RMD.AX       32.32        2.25        5.11        8.64       -2.04    -19.72
# BA          136.99       -0.52       -1.25       18.24      -42.51    -42.80
# ABNB         95.10       -0.88       -6.31       -3.87      -35.17    -54.10
# ATVI         77.79       -1.37       -0.28        4.05      -15.78    -16.08
# COIN         53.88       -2.76       -3.72        3.60      -78.25    -84.92
# ARKK         43.62       -3.00       -2.63       19.25      -64.74    -64.98
# META        162.88       -3.16       -3.90       -0.84      -53.88    -57.38
# DIS          93.64       -3.64       -3.07       -2.16      -49.21    -49.63
# BIDU        143.73       -6.82       -7.41        8.99      -20.32    -22.53
# BABA        109.57       -8.79       -7.71       11.22      -46.68    -48.98
# KWEB         29.93       -9.98      -10.68        1.70      -48.02    -49.63
# DAO           4.38      -12.92      -22.89       -7.40      -79.23    -80.98
# TAL           4.12      -18.25      -15.23        1.73      -79.79    -81.64
#
#         diff_to_60d_avg  diff_to_200d_avg
# ticker
# RMD.AX             9.14             -1.97
# BA                -3.62            -26.49
# ABNB             -21.88            -38.27
# ATVI               0.33              4.47
# COIN             -33.69            -71.89
# ARKK              -3.35            -42.63
# META             -12.55            -37.09
# DIS              -12.06            -32.64
# BIDU               7.99             -2.15
# BABA              10.81             -9.24
# KWEB               3.40            -15.33
# DAO              -22.05            -56.31
# TAL                3.40              6.65
