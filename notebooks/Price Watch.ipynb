# %% [markdown]
# # Price Watch

# %%
#imports

import yfinance as yf
import pandas as pd
import datetime as dt
import seaborn as sns
from  matplotlib import pyplot as plt

#init
sns.set_theme(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, 
            rc={'figure.figsize':(15,10)})
pd.options.display.float_format = '{:,.2f}'.format

pd.set_option('display.max_rows', None)

print('This report was refrshed at:%s'%(dt.datetime.now()))
# Out:
# This report was refrshed at:2022-03-12 18:43:46.578808

# %%
def get_price_info(ticker):
    price_info={}
    df=yf.download(ticker,start=dt.date.today()-dt.timedelta(days=366),auto_adjust=True,progress=False)
    price_info['ticker']=ticker
    price_info['last_price']=df.Close[-1]
    price_info['1w_chg_pct']=100*(df.loc[max(df.index)-dt.timedelta(weeks=1):,'Close'][-1]/df.loc[max(df.index)-dt.timedelta(weeks=1):,'Close'][0]-1)
    price_info['1m_chg_pct']=100*(df.loc[max(df.index)-dt.timedelta(days=30):,'Close'][-1]/df.loc[max(df.index)-dt.timedelta(days=30):,'Close'][0]-1)
    price_info['1y_chg_pct']=100*(df.loc[max(df.index)-dt.timedelta(days=365):,'Close'][-1]/df.loc[max(df.index)-dt.timedelta(days=365):,'Close'][0]-1)
    price_info['drawdown']=100*(df.Close[-1]/max(df.Close)-1)
    price_info['diff_to_60d_avg']=100*(df.Close[-1]/df.Close[-60:].mean()-1)
    price_info['diff_to_200d_avg']=100*(df.Close[-1]/df.Close[-200:].mean()-1)
   
    return price_info

# %% [markdown]
# ## 大类资产

# %%
#parameters
ticker_list=['SPY','QQQ','MCHI','KWEB','2822.HK','GLD','BTC-USD','GSG','VNQ','TLT']


df_price_asset=pd.DataFrame()
for ticker in ticker_list:
    try:
        price_info=get_price_info(ticker)
        df_price_asset=df_price_asset.append(price_info,ignore_index=True)
    except:
        pass

# %%
df_price_asset.set_index('ticker').sort_values(by='1w_chg_pct')
# Out:
#          last_price  1w_chg_pct  1m_chg_pct  1y_chg_pct  drawdown  \
# ticker
# KWEB          24.00      -19.35      -37.60      -70.58    -70.58
# MCHI          49.10      -11.48      -23.33      -42.99    -42.99
# GSG           23.00       -5.19       17.17       55.83    -11.03
# QQQ          324.40       -3.82      -11.54        2.49    -19.60
# TLT          134.91       -3.80       -2.41       -1.42    -12.26
# 2822.HK       15.85       -3.76       -8.06      -19.99    -24.74
# SPY          420.07       -2.80       -8.19        8.17    -12.07
# VNQ          103.67       -1.49       -2.88       18.37    -10.64
# BTC-USD   39,090.38       -0.79      -10.27      -31.82    -42.15
# GLD          185.09        0.77        8.11       14.59     -3.35
#
#          diff_to_60d_avg  diff_to_200d_avg
# ticker
# KWEB              -31.72            -47.29
# MCHI              -19.45            -28.32
# GSG                19.38             32.95
# QQQ               -10.82            -11.70
# TLT                -4.62             -6.54
# 2822.HK            -9.54            -12.76
# SPY                -6.66             -5.37
# VNQ                -3.22             -1.79
# BTC-USD            -2.91            -19.86
# GLD                 7.09              9.08

# %% [markdown]
# ## 价值投资组合

# %%
#parameters
ticker_list=['FB','MSFT','AAPL','GOOG','AMZN',
'NVDA','0700.HK','ADBE','MO','ADSK','ASML','BRK-B',
'GS','ISRG','KO','LVMUY','2318.HK','TSM','MCO'

]

df_price_value=pd.DataFrame()
for ticker in ticker_list:
    try:
        price_info=get_price_info(ticker)
        df_price_value=df_price_value.append(price_info,ignore_index=True)
    except:
        pass

# %%
df_price_value.set_index('ticker').sort_values(by='1w_chg_pct')
# Out:
#          last_price  1w_chg_pct  1m_chg_pct  1y_chg_pct  drawdown  \
# ticker
# ISRG         273.69       -9.46       -6.33       12.17    -25.10
# 0700.HK      367.80       -8.78      -23.82      -45.80    -45.80
# ADBE         416.38       -7.91      -20.20       -7.69    -39.51
# KO            57.92       -7.43       -5.11       17.43     -7.84
# ADSK         192.31       -7.39      -23.49      -29.91    -43.81
# MCO          304.47       -6.56      -11.11        5.21    -24.85
# FB           187.61       -6.22      -19.13      -31.50    -50.91
# MO            50.48       -5.63       -0.24       13.46     -5.63
# 2318.HK       54.85       -5.51      -16.26      -42.48    -42.48
# AAPL         154.73       -5.17      -12.22       27.62    -14.88
# NVDA         221.00       -3.64      -17.23       70.20    -33.77
# TSM          101.41       -3.47      -19.21      -14.56    -27.90
# MSFT         280.07       -3.38       -9.82       19.07    -18.20
# ASML         585.85       -1.43      -13.89        8.21    -33.95
# GOOG       2,609.51       -1.25       -7.76       23.39    -13.43
# GS           327.00       -0.81      -12.18       -2.55    -21.99
# AMZN       2,910.49       -0.08       -9.72       -6.52    -22.00
# BRK-B        326.60        0.39        1.31       25.18     -0.35
# LVMUY        127.93        0.75      -22.30       -4.80    -24.45
#
#          diff_to_60d_avg  diff_to_200d_avg
# ticker
# ISRG              -10.46            -15.23
# 0700.HK           -17.79            -24.76
# ADBE              -17.99            -28.77
# KO                 -4.02              2.68
# ADSK              -21.43            -31.75
# MCO               -12.91            -16.77
# FB                -32.00            -42.15
# MO                  1.26              7.27
# 2318.HK            -9.32            -13.17
# AAPL               -8.81              0.95
# NVDA              -13.94             -6.14
# TSM               -15.54            -13.67
# MSFT               -8.73             -6.33
# ASML              -15.57            -21.68
# GOOG               -5.10             -5.34
# GS                 -9.54            -13.55
# AMZN               -6.81            -12.74
# BRK-B               4.58             12.06
# LVMUY             -17.51            -17.89

# %% [markdown]
# ## 趋势投资组合

# %%
#parameters
ticker_list=['KWEB','META','ARKK','TAL','DAO','BABA','BIDU','RMD.AX','BA',
'ABNB','COIN',"DIS","ATVI"

]

df_price_trend=pd.DataFrame()
for ticker in ticker_list:
    try:
        price_info=get_price_info(ticker)
        df_price_trend=df_price_trend.append(price_info,ignore_index=True)
    except:
        pass

# %%
df_price_trend.set_index('ticker').sort_values(by='1w_chg_pct',ascending=False)
# Out:
#         last_price  1w_chg_pct  1m_chg_pct  1y_chg_pct  drawdown  \
# ticker
# ABNB        145.14        1.71      -14.39      -26.65    -30.88
# ATVI         80.31       -1.38       -1.46      -13.17    -19.03
# BA          176.23       -2.55      -18.36      -30.07    -34.53
# RMD.AX       32.83       -3.04       -3.04       35.63    -18.58
# COIN        160.07       -3.43      -25.38      -51.24    -55.21
# META         11.02       -4.42      -14.04      -26.87    -34.79
# DIS         131.75       -6.37      -10.51      -33.04    -33.18
# ARKK         55.58       -7.72      -26.97      -56.45    -57.18
# DAO           7.48      -11.16      -48.38      -77.18    -78.29
# BABA         86.71      -13.81      -31.45      -63.99    -64.46
# TAL           2.01      -15.19      -42.41      -97.07    -97.14
# BIDU        118.92      -19.24      -28.66      -56.34    -57.09
# KWEB         24.00      -19.35      -37.60      -70.58    -70.58
#
#         diff_to_60d_avg  diff_to_200d_avg
# ticker
# ABNB              -9.13             -9.86
# ATVI               7.38              2.16
# BA               -13.31            -19.01
# RMD.AX            -2.75             -5.83
# COIN             -23.87            -35.33
# META             -16.56            -23.67
# DIS              -10.71            -20.16
# ARKK             -27.89            -46.70
# DAO              -38.12            -47.95
# BABA             -26.50            -45.49
# TAL              -39.44            -76.28
# BIDU             -21.39            -26.80
# KWEB             -31.72            -47.29
