# %% [markdown]
#  # KWEB数据分析

# %%
#imports

import yfinance as yf
import pandas as pd
import datetime as dt
import getdata as gd
import warnings


warnings.filterwarnings('ignore')

# %%
print('This notebook was refreshed at %s'%(dt.datetime.now()))
# Out:
# This notebook was refreshed at 2022-01-11 18:24:43.925289

# %% [markdown]
# 本笔记分析KWEB的数据以回答以下问题：
# 1. 当前的估值是否合理？
# 2. 中短期趋势如何？（未完待续）

# %%
#init

pd.options.display.float_format = '{:,.2f}'.format
df_port=pd.read_csv('../data/share/kweb_holdings.csv')

# %% [markdown]
# ## 成分股基本面监测

# %%
# df_stock=gd.get_port_holding_info(df_port)
# df_stock.to_csv('../data/share/kweb_holidngs_info.csv')

# %%
df_stock=pd.read_csv('../data/share/kweb_holidngs_info.csv')

# %%
df_metric=gd.get_port_holding_metric(df_stock)

# %%
df_metric.reindex(columns=['ticker','weight','price','drawdown','pcf','pe_ttm',
                'pe_fwd','est_eps_growth','peg','roe','cf_margin','net_margin'])\
                .sort_values(by='drawdown')\
                .style.format(precision=2,thousands=',',formatter={'weight':'{:.3f}',
                                                                    'drawdown':'{:.1f}%',
                                                                    'est_eps_growth':'{:.1f}%',
                                                                    'gross_margin':'{:.1f}%',
                                                                    'cf_margin':'{:.1f}%',
                                                                    'net_margin':'{:.1f}%',

                                                                
                                                                
                                                                    
                                                                    })
# Out:
# <style type="text/css">
# </style>
# <table id="T_1b66d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ticker</th>
#       <th class="col_heading level0 col1" >weight</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >drawdown</th>
#       <th class="col_heading level0 col4" >pcf</th>
#       <th class="col_heading level0 col5" >pe_ttm</th>
#       <th class="col_heading level0 col6" >pe_fwd</th>
#       <th class="col_heading level0 col7" >est_eps_growth</th>
#       <th class="col_heading level0 col8" >peg</th>
#       <th class="col_heading level0 col9" >roe</th>
#       <th class="col_heading level0 col10" >cf_margin</th>
#       <th class="col_heading level0 col11" >net_margin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b66d_level0_row0" class="row_heading level0 row0" >52</th>
#       <td id="T_1b66d_row0_col0" class="data row0 col0" >GOTU</td>
#       <td id="T_1b66d_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_1b66d_row0_col2" class="data row0 col2" >1.65</td>
#       <td id="T_1b66d_row0_col3" class="data row0 col3" >-98.8%</td>
#       <td id="T_1b66d_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_1b66d_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_1b66d_row0_col6" class="data row0 col6" >-9.17</td>
#       <td id="T_1b66d_row0_col7" class="data row0 col7" >-92.7%</td>
#       <td id="T_1b66d_row0_col8" class="data row0 col8" >-0.64</td>
#       <td id="T_1b66d_row0_col9" class="data row0 col9" >-151.78</td>
#       <td id="T_1b66d_row0_col10" class="data row0 col10" >nan%</td>
#       <td id="T_1b66d_row0_col11" class="data row0 col11" >-46.8%</td>
#     </tr>
#     <tr>
#       <th id="T_1b66d_level0_row1" class="row_heading level0 row1" >34</th>
#       <td id="T_1b66d_row1_col0" class="data row1 col0" >TAL</td>
#       <td id="T_1b66d_row1_col1" class="data row1 col1" >0.006</td>
#       <td id="T_1b66d_row1_col2" class="data row1 col2" >3.31</td>
#       <td id="T_1b66d_row1_col3" class="data row1 col3" >-96.3%</td>
#       <td id="T_1b66d_row1_col4" class="data row1 col4" >2.24</td>
#       <td id="T_1b66d_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T
level0_row5" class="row_heading level0 row5" >36</th>
#       <td id="T_1b66d_row5_col0" class="data row5 col0" >IQ</td>
#       <td id="T_1b66d_row5_col1" class="data row5 col1" >0.006</td>
#       <td id="T_1b66d_row5_col2" class="data row5 col2" >4.61</td>
#       <td id="T_1b66d_row5_col3" class="data row5 col3" >-84.1%</td>
#       <td id="T_1b66d_row5_col4" class="data row5 col4" >-3.64</td>
#       <td id="T_1b66d_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_1b66d_row5_col6" class="data row5 col6" >-4.90</td>
#       <td id="T_1b66d_row5_col7" class="data row5 col7" >-21.3%</td>
#       <td id="T_1b66d_row5_col8" class="data row5 col8" >-2.15</td>
#       <td id="T_1b66d_row5_col9" class="data row5 col9" >-93.86</td>
#       <td id="T_1b66d_row5_col10" class="data row5 col10" >-20.8%</td>
#       <td id="T_1b66d_row5_col11" class="data row5 col11" >-19.4%</td>
#     </tr>
#     <tr>
#       <th id="T_1b66d_level0_row6" class="row_heading level0 row6" >35</th>
#       <td id="T_1b66d_row6_col0" class="data row6 col0" >KC</td>
#       <td id="T_1b66d_row6_col1" class="data row6 col1" >0.006</td>
#       <td id="T_1b66d_row6_col2" class="data row6 col2" >13.72</td>
#       <td id="T_1b66d_row6_col3" class="data row6 col3" >-81.0%</td>
#       <td id="T_1b66d_row6_col4" class="data row6 col4" >-20.61</td>
#       <td id="T_1b66d_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_1b66d_row6_col6" class="data row6 col6" >-22.13</td>
#       <td id="T_1b66d_row6_col7" class="data row6 col7" >-27.3%</td>
#       <td id="T_1b66d_row6_col8" class="data row6 col8" >nan</td>
#       <td id="T_1b66d_row6_col9" class="data row6 col9" >-11.90</td>
#       <td id="T_1b66d_row6_col10" class="data row6 col10" >-12.3%</td>
#       <td id="T_1b66d_row6_col11" class="data row6 col11" >-14.6%</td>
#     </tr>
#     <tr>
#       <th id="T_1b66d_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_1b66d_row7_col0" class="data row7 col0" >1024.HK</td>
#       <td id="T_1b66d_row7_col1" class="data row7 col1" >0.037</td>
#       <td id="T_1b66d_row7_col2" class="data row7 col2" >79.90</td>
#       <td id="T_1b66d_row7_col3" class="data row7 col3" >-80.7%</td>
#       <td id="T_1b66d_row7_col4" class="data row7 col4" >-100.87</td>
#       <td id="T_1b66d_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_1b66d_row7_col6" class="data row7 col6" >-20.03</td>
#       <td id="T_1b66d_row7_col7" class="data row7 col7" >nan%</td>
#       <td id="T_1b66d_row7_col8" class="data row7 col8" >nan</td>
#       <td id="T_1b66d_row7_col9" class="data row7 col9" >nan</td>
#       <td id="T_1b66d_row7

# %% [markdown]
# ## 整体基本面分析

# %% [markdown]
# 若把整个ETF当成一个整体，按成分股权重计算，各项基本面指标如下：

# %%
df_port_metric=gd.get_port_metric(df_metric)

# %%
df_port_metric.columns=['KWEB']
df_port_metric
# Out:
#                              KWEB
# market_cap     132,457,555,083.97
# revenue         39,304,252,688.85
# revenue_growth              23.29
# ps                           3.37
# gross_profit    11,484,655,235.21
# pgp                         11.53
# gross_margin                29.22
# cashflow         7,251,549,975.65
# pcf                         18.27
# cf_rate                      5.47
# cf_margin                   18.45
# net_income       4,879,598,047.34
# pe                          27.15
# income_rate                  3.68
# profit_margin               12.41
# est_net_income   7,893,796,081.87
# fwd_pe                      16.78
