# %% [markdown]
#  # KWEB数据分析

# %%
#imports

import yfinance as yf
import pandas as pd
import datetime as dt
import getdata as gd
import warnings


warnings.filterwarnings('ignore')

# %%
print('This notebook was refreshed at %s'%(dt.datetime.now()))
# Out:
# This notebook was refreshed at 2022-05-02 11:15:43.302136

# %% [markdown]
# 本笔记分析KWEB的数据以回答以下问题：
# 1. 当前的估值是否合理？
# 2. 中短期趋势如何？（未完待续）

# %%
#init

pd.options.display.float_format = '{:,.2f}'.format
df_port=pd.read_csv('../data/share/kweb_holdings.csv')

# %% [markdown]
# ## 成分股基本面监测

# %%
df_stock=gd.get_port_holding_info(df_port)
df_stock.to_csv('../data/share/kweb_holidngs_info.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df_stock=pd.read_csv('../data/share/kweb_holidngs_info.csv')

# %%
df_metric=gd.get_port_holding_metric(df_stock)

# %%
df_metric.reindex(columns=['ticker','weight','price','drawdown','1w_chg_pct','pcf','pe_ttm',
                'pe_fwd','est_eps_growth','peg','roe','cf_margin','net_margin'])\
                .sort_values(by='drawdown')\
                .style.format(precision=2,thousands=',',formatter={'weight':'{:.3f}',
                                                                    'drawdown':'{:.1f}%',
                                                                    'est_eps_growth':'{:.1f}%',
                                                                    'gross_margin':'{:.1f}%',
                                                                    'cf_margin':'{:.1f}%',
                                                                    'net_margin':'{:.1f}%',

                                                                
                                                                
                                                                    
                                                                    })
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5c6f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ticker</th>
#       <th class="col_heading level0 col1" >weight</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >drawdown</th>
#       <th class="col_heading level0 col4" >1w_chg_pct</th>
#       <th class="col_heading level0 col5" >pcf</th>
#       <th class="col_heading level0 col6" >pe_ttm</th>
#       <th class="col_heading level0 col7" >pe_fwd</th>
#       <th class="col_heading level0 col8" >est_eps_growth</th>
#       <th class="col_heading level0 col9" >peg</th>
#       <th class="col_heading level0 col10" >roe</th>
#       <th class="col_heading level0 col11" >cf_margin</th>
#       <th class="col_heading level0 col12" >net_margin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5c6f_level0_row0" class="row_heading level0 row0" >52</th>
#       <td id="T_f5c6f_row0_col0" class="data row0 col0" >GOTU</td>
#       <td id="T_f5c6f_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_f5c6f_row0_col2" class="data row0 col2" >1.59</td>
#       <td id="T_f5c6f_row0_col3" class="data row0 col3" >-95.0%</td>
#       <td id="T_f5c6f_row0_col4" class="data row0 col4" >4.61</td>
#       <td id="T_f5c6f_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_f5c6f_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_f5c6f_row0_col7" class="data row0 col7" >-8.83</td>
#       <td id="T_f5c6f_row0_col8" class="data row0 col8" >-92.7%</td>
#       <td id="T_f5c6f_row0_col9" class="data row0 col9" >-0.64</td>
#       <td id="T_f5c6f_row0_col10" class="data row0 col10" >-151.78</td>
#       <td id="T_f5c6f_row0_col11" class="data row0 col11" >nan%</td>
#       <td id="T_f5c6f_row0_col12" class="data row0 col12" >-46.8%</td>
#     </tr>
#     <tr>
#       <th id="T_f5c6f_level0_row1" class="row_heading level0 row1" >34</th>
#       <td id="T_f5c6f_row1_col0" class="data row1 col0" >TAL</td>
#       <td id="T_f5c6f_row1_col1" class="data row1 col1" >0.001</td>
#       <td id="T_f5c6f_row1_col2" class="data row1 col2" >3.39</td>
#       <td id="T_f5c6f_row1_col3" class="data row1 col3" >-94.0%</td>
#       <td id="T_f5c6f_row1_col4" class="data row1 col4" >20.21</td>
#       <td id="T_f5c6f_row1_col5" class="data row1 col5" >2.29</td>
#       <td id="T_f5c6f_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_f5c6f_row1_col7" class="data row1 col7" >6.52</td>
#       <td id="T_f5c6f_row1_col8" class="data row1 col8" >-373.7%</td>
#       <td id="T_f5c6f_row1_col9" class="data row1 col9" >0.38</td>
#       <td id="T_f5c6f_row1_col10" class="data row1 col10" >-3.69</td>
#       <td id="T_f5c6f_row1_col11" class="data row1 col11" >21.2%</td>
#       <td id="T_f5c6f_row1_col12" class="data row1 col12" >-2.6%</td>
#     </tr>
#     <tr>
#       <th id="T_f5c6f_level0_row2" class="row_heading level0 row2" >51</th>
#       <td id="T_f5c6f_row2_col0" class="data row2 col0" >OCFT</td>
#       <td id="T_f5c6f_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_f5c6f_row2_col2" class="data row2 col2" >1.37</td>
#       <td id="T_f5c6f_row2_col3" class="data row2 col3" >-92.8%</td>
#       <td id="T_f5c6f_row2_col4" class="data row2 col4" >0.74</td>
#       <td id="T_f5c6f_row2_col5" class="data row2 col5" >-8.73</td>
#       <td id="T_f5c6f_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_f5c6f_row2_col7" class="data row2 col7" >-4.42</td>
#       <td id="T_f5c6f_row2_col8" class="data row2 col8" >-43.3%</td>
#       <td id="T_f5c6f_row2_col9" class="data row2 col9" >-3.69</td>
#       <td id="T_f5c6f_row2_col10" class="data row2 col10" >-29.18</td>
#       <td id="T_f5c6f_row2_col11" class="data row2 col11" >-9.8%</td>
#       <td id="T_f5c6f_row2_col12" class="data row2 col12" >-31.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f5c6f_level0_row3" class="row_heading level0 row3" >35</th>
#       <td id="T_f5c6f_row3_col0" class="data row3 col0" >KC</td>
#       <td id="T_f5c6f_row3_col1" class="data row3 col1" >0.000</td>
#       <td id="T_f5c6f_row3_col2" class="data row3 col2" >3.62</td>
#       <td id="T_f5c6f_row3_col3" class="data row3 col3" >-91.8%</td>
#       <td id="T_f5c6f_row3_col4" class="data row3 col4" >4.32</td>
#       <td id="T_f5c6f_row3_col5" class="data row3 col5" >-5.64</td>
#       <td id="T_f5c6f_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_f5c6f_row3_col7" class="data row3 col7" >-5.84</td>
#       <td id="T_f5c6f_row3_col8" class="data row3 col8" >-27.3%</td>
#       <td id="T_f5c6f_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_f5c6f_row3_col10" class="data row3 col10" >-11.90</td>
#       <td id="T_f5c6f_row3_col11" class="data row3 col11" >-12.3%</td>
#       <td id="T_f5c6f_row3_col12" class="data row3 col12" >-14.6%</td>
#     </tr>
#     <tr>
#       <th id="T_f5c6f_level0_row4" class="row_heading level0 row4" >24</th>
#       <td id="T_f5c6f_row4_col0" class="data row4 col0" >ZH</td>
#       <td id="T_f5c6f_row4_col1" class="data row4 col1" >0.000</td>
#       <td id="T_f5c6f_row4_col2" class="data row4 col2" >1.55</td>
#       <td id="T_f5c6f_row4_col3" class="data row4 col3" >-88.6%</td>
#       <td id="T_f5c6f_row4_col4" class="data row4 col4" >-0.64</td>
#       <td id="T_f5c6f_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_f5c6f_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_f5c6f_row4_col7" class="data row4 col7" >-7.38</td>
#       <td id="T_f5c6f_row4_col8" class="data row4 col8" >-63.8%</td>
#       <td id="T_f5c6f_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_f5c6f_row4_col10" class="data row4 col10" >-20.37</td>
#       <td id="T_f5c6f_row4_col11" class="data row4 col11" >nan%</td>
#       <td id="T_f5c6f_row4_col12" class="data row4 col12" >-40.9%</td>
#     </tr>
#     <tr>
#       <th id="T_f5c6f_level0_row5" class="row_heading level0 row5" >41</th>
#       <td id="T_f5c6f_row5_col0" class="data row5 col0" >API</td>
#       <td id="T_f5c6f_row5_col1" class="data row5 col1" >0.000</td>
#       <td id="T_f5c6f_row5_col2" class="data row5 col2" >7.37</td>
#       <td id="T_f5c6f_row5_col3" class="data row5 col3" >-84.9%</td>
#       <td id="T_f5c6f_row5_col4" class="data row5 col4" >8.38</td>
#       <td id="T_f5c6f_row5_col5" class="data row5 col5" >-42.70</td>
#       <td id="T_f5c6f_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_f5c6f_row5_col7" class="data row5 col7" >-13.16</td>
#       <td id="T_f5c6f_row5_col8" class="data row5 col8" >5.3%</td>
#       <td id="T_f5c6f_row5_col9" class="data row5 col9" >0.15</td>
#       <td id="T_f5c6f_row5_col10" class="data row5 col10" >-9.50</td>
#       <td id="T_f5c6f_row5_col11" class="data row5 col11" >-11.9%</td>
#       <td id="T_f5c6f_row5_col12" class="data row5 col12" >-43.1%</td>
#     </tr>
#     <tr>
#       <th id="T_f5c6f_level0_row6" class="row_heading level0 row6" >38</th>
#       <td id="T_f5c6f_row6_col0" class="data row6 col0" >2158.HK</td>
#       <td id="T_f5c6f_row6_col1" class="data row6 col1" >0.001</td>
#       <td id="T_f5c6f_row6_col2" class="data row6 col2" >8.31</td>
#       <td id="T_f5c6f_row6_col3" class="data row6 col3" >-82.7%</td>
#       <td id="T_f5c6f_row6_col4" class="data row6 col4" >-1.42</td>
#       <td id="T_f5c6f_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_f5c6f_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_f5c6f_row6_col7" class="data row6 col7" >nan</td>
#       <td id="T_f5c6f_row6_col8" class="data row6 col8" >nan%</td>
#       <td id="T_f5c6f_row6_col9" class="data row6 col9" >nan</td>
#       <td id="T_f5c6f_row6_col10" class="data row6 col10" >nan</td>
#       <td id="T_f5c6f_row6_col11" class="data row6 col11" >nan%</td>
#       <td id="T_f5c6f_row6_col12" class="data row6 col12" >-278.2%</td>
#     </tr>
#     <tr>
#       <th id="T_f5c6f_level0_row7" class="row_heading level0 row7" >15</th>
#       <td id="T_f5c6f_row7_col0" class="data row7 col0" >BILI</td>
#       <td id="T_f5c6f_row7_col1" class="data row7 col1" >0.005</td>
#       <td id="T_f5c6f_row7_col2" class

# %% [markdown]
# ## 整体基本面分析

# %% [markdown]
# 若把整个ETF当成一个整体，按成分股权重计算，各项基本面指标如下：

# %%
df_port_metric=gd.get_port_metric(df_metric)

# %%
df_port_metric.columns=['KWEB']
df_port_metric
# Out:
#                                 KWEB
# market_cap        234,204,516,227.80
# revenue            80,841,125,224.75
# revenue_growth                 16.95
# ps                              2.90
# gross_profit       25,777,780,553.96
# pgp                             9.09
# gross_margin                   31.89
# cashflow           16,396,061,129.62
# pcf                            14.28
# cf_rate                         7.00
# cf_margin                      20.28
# net_income         12,717,377,030.71
# pe                             18.42
# income_rate                     5.43
# profit_margin                  15.73
# est_net_income     19,065,457,048.99
# fwd_pe                         12.28
# fwd_income_growth              49.92
