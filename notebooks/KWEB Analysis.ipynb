# %% [markdown]
#  # KWEB数据分析

# %%
#imports

import yfinance as yf
import pandas as pd
import datetime as dt
import getdata as gd
import warnings


warnings.filterwarnings('ignore')

# %%
print('This notebook was refreshed at %s'%(dt.datetime.now()))
# Out:
# This notebook was refreshed at 2022-01-08 18:14:22.747772

# %% [markdown]
# 本笔记分析KWEB的数据以回答以下问题：
# 1. 当前的估值是否合理？
# 2. 中短期趋势如何？（未完待续）

# %%
#init

pd.options.display.float_format = '{:,.2f}'.format
df_port=pd.read_csv('../data/share/kweb_holdings.csv')

# %% [markdown]
# ## 成分股基本面监测

# %%
#df_stock=gd.get_port_holding_info(df_port)
# df_stock.to_csv('../data/share/kweb_holidngs_info.csv')

# %%
df_stock=pd.read_csv('../data/share/kweb_holidngs_info.csv')
df_metric=gd.get_port_holding_metric(df_stock)

# %%
df_metric.reindex(columns=['ticker','weight','price','drawdown_from_52w_peak','roe','pcf','pe_ttm',
                'pe_fwd','peg','gross_margin','cf_margin'])\
                .sort_values(by='drawdown_from_52w_peak')\
                .style.format(precision=2,thousands=',',formatter={'weight':'{:.3f}',
                                                                    'drawdown_from_52w_peak':'{:.1f}%',
                                                                    'gross_margin':'{:.2f}%',
                                                                    'cf_margin':'{:.2f}%',
                                                                
                                                                    
                                                                    })
# Out:
# <style type="text/css">
# </style>
# <table id="T_eed7e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ticker</th>
#       <th class="col_heading level0 col1" >weight</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >drawdown_from_52w_peak</th>
#       <th class="col_heading level0 col4" >roe</th>
#       <th class="col_heading level0 col5" >pcf</th>
#       <th class="col_heading level0 col6" >pe_ttm</th>
#       <th class="col_heading level0 col7" >pe_fwd</th>
#       <th class="col_heading level0 col8" >peg</th>
#       <th class="col_heading level0 col9" >gross_margin</th>
#       <th class="col_heading level0 col10" >cf_margin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eed7e_level0_row0" class="row_heading level0 row0" >52</th>
#       <td id="T_eed7e_row0_col0" class="data row0 col0" >GOTU</td>
#       <td id="T_eed7e_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_eed7e_row0_col2" class="data row0 col2" >1.65</td>
#       <td id="T_eed7e_row0_col3" class="data row0 col3" >-98.8%</td>
#       <td id="T_eed7e_row0_col4" class="data row0 col4" >-1.52</td>
#       <td id="T_eed7e_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_eed7e_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_eed7e_row0_col7" class="data row0 col7" >-9.17</td>
#       <td id="T_eed7e_row0_col8" class="data row0 col8" >-0.64</td>
#       <td id="T_eed7e_row0_col9" class="data row0 col9" >0.64%</td>
#       <td id="T_eed7e_row0_col10" class="data row0 col10" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_eed7e_level0_row1" class="row_heading level0 row1" >34</th>
#       <td id="T_eed7e_row1_col0" class="data row1 col0" >TAL</td>
#       <td id="T_eed7e_row1_col1" class="data row1 col1" >0.006</td>
#       <td id="T_eed7e_row1_col2" class="data row1 col2" >3.42</td>
#       <td id="T_eed7e_row1_col3" class="data row1 col3" >-96.2%</td>
#       <td id="T_eed7e_row1_col4" class="data row1 col4" >-0.04</td>
#       <td id="T_eed7e_row1_col5" class="data row1 col5" >2.31</td>
#       <td id="T_eed7e_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_eed7e_row1_col7" class="data row1 col7" >6.58</td>
#       <td id="T_eed7e_row1_col8" class="data row1 col8" >0.38</td>
#       <td id="T_eed7e_row1_col9" class="data row1 col9" >0.54%</td>
#       <td id="T_eed7e_row1_col10" class="data row1 col10" >0.21%</td>
#     </tr>
#     <tr>
#       <th id="T_eed7e_level0_row2" class="row_heading level0 row2" >51</th>
#       <td id="T_eed7e_row2_col0" class="data row2 col0" >OCFT</td>
#       <td id="T_eed7e_row2_col1" class="data row2 col1" >0.001</td>
#       <td id="T_eed7e_row2_col2" class="data row2 col2" >2.29</td>
#       <td id="T_eed7e_row2_col3" class="data row2 col3" >-89.8%</td>
#       <td id="T_eed7e_row2_col4" class="data row2 col4" >-0.26</td>
#       <td id="T_eed7e_row2_col5" class="data row2 col5" >-33.87</td>
#       <td id="T_eed7e_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_eed7e_row2_col7" class="data row2 col7" >-7.39</td>
#       <td id="T_eed7e_row2_col8" class="data row2 col8" >-3.69</td>
#       <td id="T_eed7e_row2_col9" class="data row2 col9" >0.32%</td>
#       <td id="T_eed7e_row2_col10" class="data row2 col10" >-0.04%</td>
#     </tr>
#     <tr>
#       <th id="T_eed7e_level0_row3" class="row_heading level0 row3" >50</th>
#       <td id="T_eed7e_row3_col0" class="data row3 col0" >DOYU</td>
#       <td id="T_eed7e_row3_col1" class="data row3 col1" >0.001</td>
#       <td id="T_eed7e_row3_col2" class="data row3 col2" >2.49</td>
#       <td id="T_eed7e_row3_col3" class="data row3 col3" >-87.0%</td>
#       <td id="T_eed7e_row3_col4" class="data row3 col4" >-0.09</td>
#       <td id="T_eed7e_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_eed7e_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_eed7e_row3_col7" class="data row3 col7" >-49.80</td>
#       <td id="T_eed7e_row3_col8" class="data row3 col8" >-2.82</td>
#       <td id="T_eed7e_row3_col9" class="data row3 col9" >0.17%</td>
#       <td id="T_eed7e_row3_col10" class="data row3 col10" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_eed7e_level0_row4" class="row_heading level0 row4" >41</th>
#       <td id="T_eed7e_row4_col0" class="data row4 col0" >API</td>
#       <td id="T_eed7e_row4_col1" class="data row4 col1" >0.005</td>
#       <td id="T_eed7e_row4_col2" class="data row4 col2" >14.40</td>
#       <td id="T_eed7e_row4_col3" class="data row4 col3" >-86.4%</td>
#       <td id="T_eed7e_row4_col4" class="data row4 col4" >-0.07</td>
#       <td id="T_eed7e_row4_col5" class="data row4 col5" >-72.29</td>
#       <td id="T_eed7e_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_eed7e_row4_col7" class="data row4 col7" >-25.71</td>
#       <td id="T_eed7e_row4_col8" class="data row4 col8" >0.15</td>
#       <td id="T_eed7e_row4_col9" class="data row4 col9" >0.54%</td>
#       <td id="T_eed7e_row4_col10" class="data row4 col10" >-0.14%</td>
#     </tr>
#     <tr>
#       <th id="T_eed7e_level0_row5" class="row_heading level0 row5" >36</th>
#       <td id="T_eed7e_row5_col0" class="data row5 col0" >IQ</td>
#       <td id="T_eed7e_row5_col1" class="data row5 col1" >0.006</td>
#       <td id="T_eed7e_row5_col2" class="data row5 col2" >4.43</td>
#       <td id="T_eed7e_row5_col3" class="data row5 col3" >-84.7%</td>
#       <td id="T_eed7e_row5_col4" class="data row5 col4" >-0.94</td>
#       <td id="T_eed7e_row5_col5" class="data row5 col5" >-3.50</td>
#       <td id="T_eed7e_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_eed7e_row5_col7" class="data row5 col7" >-4.71</td>
#       <td id="T_eed7e_row5_col8" class="data row5 col8" >-2.15</td>
#       <td id="T_eed7e_row5_col9" class="data row5 col9" >0.09%</td>
#       <td id="T_eed7e_row5_col10" class="data row5 col10" >-0.21%</td>
#     </tr>
#     <tr>
#       <th id="T_eed7e_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_eed7e_row6_col0" class="data row6 col0" >1024.HK</td>
#       <td id="T_eed7e_row6_col1" class="data row6 col1" >0.037</td>
#       <td id="T_eed7e_row6_col2" class="data row6 col2" >70.75</td>
#       <td id="T_eed7e_row6_col3" class="data row6 col3" >-83.0%</td>
#       <td id="T_eed7e_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_eed7e_row6_col5" class="data row6 col5" >-89.41</td>
#       <td id="T_eed7e_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_eed7e_row6_col7" class="data row6 col7" >-17.82</td>
#       <td id="T_eed7e_row6_col8" class="data row6 col8" >nan</td>
#       <td id="T_eed7e_row6_col9" class="data row6 col9" >0.32%</td>
#       <td id="T_eed7e_row6_col10" class="data row6 col10" >-0.04%</td>
#     </tr>
#     <tr>
#       <th id="T_eed7e_level0_row7" class="row_heading level0 row7" >35</th>
#       <td id="T_eed7e_row7_col0" class="data row7 col0" >KC</td>
#       <td id="T_eed7e_row7_col1" class="data row7 col1" >0.006</td>
#       <td id="T_eed7e_row7_col2" class="data row7 col2" >13.50</td>
#       <td id="T_eed7e_row7_col3" class="data row7 col3" >-81.3%</td>
#       <td id="T_eed7e_row7_col4" class="data row7 col4" >-0.12</td>
#       <td id="T_eed7e_row7_col5" class="data row7 col5" >-20.31</td>
#       <td id="T_eed7e_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_eed7e_row7_col7" class="data row7 col7" >-21.77</td>
#       <td id="T_eed7e_row7_col8" class="data row7 col8" >nan</td>
#       <td id="T_eed7e_row7_col9" class="data row7 col9" >0.04%</td>
#       <td id="T_eed7e_row7_col10" class="data row7 col10" >-0.12%</td>
#     </tr>
#     <tr>
#       <th id="T_eed7e_level0_row8" class="row_heading level0 row8" >32</th>
#       <td id="T_eed7e_row8_col0" class="data row8 col0" >1833.HK</td>
#       <td id="T_eed7e_row8_col1" class="data row8 col1" >0.007</td>
#       <td id="T_eed7e_row8_col2" class="data row8 col2" >26.65</td>
#       <td id="T_eed7e_row8_col3" class="data row8 col3" >-80.8%</td>
#       <td id="T_eed7e_row8_col4" class="data row8 col4" >-0.13</td>
#       <td id="T_eed7e_row8_col5" class="data row8 col5" >-24.03</td>

# %% [markdown]
# ## 整体基本面分析

# %% [markdown]
# 若把整个ETF当成一个整体，按成分股权重计算，各项基本面指标如下：

# %%
df_port_metric=gd.get_port_metric(df_metric)

# %%
df_port_metric.columns=['Value']
df_port_metric
# Out:
#                             Value
# market_cap     129,948,352,305.99
# revenue         39,244,005,489.64
# revenue_growth              18.89
# ps                           3.31
# gross_profit    11,467,114,583.62
# pgp                         11.33
# gross_margin                29.22
# cashflow         7,240,434,338.10
# pcf                         17.95
# cf_rate                      5.57
# cf_margin                   18.45
# net_income       4,872,102,803.13
# pe                          26.67
# income_rate                  3.75
# profit_margin               12.41
